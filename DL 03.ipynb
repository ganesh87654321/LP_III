# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Conv2D,Dense,MaxPooling2D
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.datasets import mnist

# %% [markdown]
# # Loading and preparing the data

# %%
(X_train,y_train),(X_test,y_test) = mnist.load_data()

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
X_train[0].min(), X_train[0].max()
# Out:
# (0, 255)

# %%
X_train = (X_train - 0.0) / (255.0 - 0.0)
X_test = (X_test - 0.0) / (255.0 - 0.0)
X_train[0].min(), X_train[0].max()
# Out:
# (0.0, 1.0)

# %%
def plot_digit(image, digit, plt, i):
 plt.subplot(4, 5, i + 1)
 plt.imshow(image, cmap=plt.get_cmap('gray'))
 plt.title(f"Digit: {digit}")
 plt.xticks([])
 plt.yticks([])
plt.figure(figsize=(16, 10))
for i in range(20):
 plot_digit(X_train[i], y_train[i], plt, i) 
plt.show()

# %%
X_train = X_train.reshape((X_train.shape + (1,)))
X_test = X_test.reshape((X_test.shape + (1,)))
y_train[0:20]
# Out:
# array([5, 0, 4, 1, 9, 2, 1, 3, 1, 4, 3, 5, 3, 6, 1, 7, 2, 8, 6, 9],
#       dtype=uint8)

# %% [markdown]
# # Creating the Model

# %%
model = Sequential([
 Conv2D(32, (3, 3), activation="relu", input_shape=(28, 28, 1)),
 MaxPooling2D((2, 2)),
 Flatten(),
 Dense(100, activation="relu"),
 Dense(10, activation="softmax")
])

# %%
optimizer = SGD(learning_rate=0.01, momentum=0.9)
model.compile(
 optimizer=optimizer, 
 loss="sparse_categorical_crossentropy", 
 metrics=["accuracy"]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  flatten (Flatten)           (None, 5408)              0
#
#  dense (Dense)               (None, 100)               540900
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 542,230
# Trainable params: 542,230
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train the Model

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.2293 - accuracy: 0.9314 - val_loss: 0.0993 - val_accuracy: 0.9683
# Epoch 2/10
# 1875/1875 [==============================] - 38s 20ms/step - loss: 0.0751 - accuracy: 0.9772 - val_loss: 0.0535 - val_accuracy: 0.9831
# Epoch 3/10
# 1875/1875 [==============================] - 32s 17ms/step - loss: 0.0495 - accuracy: 0.9851 - val_loss: 0.0506 - val_accuracy: 0.9824
# Epoch 4/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0355 - accuracy: 0.9892 - val_loss: 0.0440 - val_accuracy: 0.9846
# Epoch 5/10
# 1875/1875 [==============================] - 31s 17ms/step - loss: 0.0261 - accuracy: 0.9921 - val_loss: 0.0459 - val_accuracy: 0.9851
# Epoch 6/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0201 - accuracy: 0.9938 - val_loss: 0.0414 - val_accuracy: 0.9855
# Epoch 7/10
# 1875/1875 [==============================] - 30s 16ms/step - loss: 0.0146 - accuracy: 0.9956 - val_loss: 0.0429 - val_accuracy: 0.9859
# Epoch 8/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0111 - accuracy: 0.9968 - val_loss: 0.0435 - val_accuracy: 0.9859
# Epoch 9/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0415 - val_accuracy: 0.9865
# Epoch 10/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0422 - val_accuracy: 0.9866

# %%
plt.figure(figsize=(16, 10))
for i in range(20):
 image = random.choice(X_test).squeeze()
 digit = np.argmax(model.predict(image.reshape((1, 28, 28, 1)))[0], axis=-1)
 plot_digit(image, digit, plt, i)
plt.show()
# Out:
# 1/1 [==============================] - 0s 267ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step

# %%
predictions = np.argmax(model.predict(X_test), axis=-1)
accuracy_score(y_test, predictions)
# Out:
# 313/313 [==============================] - 2s 5ms/step
# 0.9866

# %% [markdown]
# # Estimating the model's performance

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])    #Test Loss
print('Test accuracy:', score[1])    #Test Accuracy
# Out:
# Test loss: 0.04222051054239273
# Test accuracy: 0.9865999817848206

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = 10
epochs_range = range(epochs)

# %%
import os
# plotting the metrics
fig = plt.figure()
plt.figure(figsize=(8, 8))

plt.subplot(2,1,1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')


plt.subplot(2,1,2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.tight_layout()

# %%
#Save the model
# serialize model to JSON
model_digit_json = model.to_json()
with open("model_digit.json", "w") as json_file:
 json_file.write(model_digit_json)
# serialize weights to HDF5
model.save_weights("model_digit.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
